# %%
import pstats
from pstats import SortKey

# %%
p = pstats.Stats('profiling')

# %%
p.sort_stats(SortKey.TIME).print_stats()
# Out:
# Sun May 30 16:52:48 2021    profiling
#
#          109575626 function calls (107670584 primitive calls) in 1405.561 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      3000  619.721    0.207  619.721    0.207 {method 'run_backward' of 'torch._C._EngineBase' objects}
#      9000   88.937    0.010   88.937    0.010 {method 'item' of 'torch._C._TensorBase' objects}
#   1587060   71.435    0.000   71.435    0.000 {built-in method tensor}
#   1587060   68.787    0.000  115.503    0.000 appfoq.py:140(__call__)
#     12970   66.207    0.005  256.413    0.020 appfoq.py:26(negative_sampling)
#   1587060   56.760    0.000   56.760    0.000 {built-in method embedding}
#   1652880   46.979    0.000   46.979    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#   1587060   46.716    0.000   46.716    0.000 {built-in method clamp}
#   1521240   36.819    0.000   73.977    0.000 arraysetops.py:484(in1d)
# ...
